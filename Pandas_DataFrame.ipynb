# %% [markdown]
# ------- Creating & Understanding Python DataFrame using Pandas library --------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

emp = pd.DataFrame({
    "emp_id": [1,2,3,4,5,6,7,8],
    "name": ["Shashi","Yash","Veman","Vansh","Nikki","Om","Saiyam","Vidyasagar"],
    "age": [24,23,22,23,24,21,25,28],
    "sal": [20000,25000,3000,35000,45000,35678,34000,89000],
    "appraisal": [1200,1200,1200,1200,1200,1200,1200,1200]
})

emp
# Out:
#    emp_id        name  age    sal  appraisal
# 0       1      Shashi   24  20000       1200
# 1       2        Yash   23  25000       1200
# 2       3       Veman   22   3000       1200
# 3       4       Vansh   23  35000       1200
# 4       5       Nikki   24  45000       1200
# 5       6          Om   21  35678       1200
# 6       7      Saiyam   25  34000       1200
# 7       8  Vidyasagar   28  89000       1200

# %%
emp.tail(2)
# Out:
#    emp_id        name  age    sal  appraisal
# 6       7      Saiyam   25  34000       1200
# 7       8  Vidyasagar   28  89000       1200

# %%
emp.head(2)
# Out:
#    emp_id    name  age    sal  appraisal
# 0       1  Shashi   24  20000       1200
# 1       2    Yash   23  25000       1200

# %%
#emp.drop("sal", axis=1)

#emp
# Out:
#    emp_id        name  age    sal  appraisal
# 0       1      Shashi   24  20000       1200
# 1       2        Yash   23  25000       1200
# 2       3       Veman   22   3000       1200
# 3       4       Vansh   23  35000       1200
# 4       5       Nikki   24  45000       1200
# 5       6          Om   21  35678       1200
# 6       7      Saiyam   25  34000       1200
# 7       8  Vidyasagar   28  89000       1200

# %%
emp["new_sal"] = emp["sal"] + emp["appraisal"]

emp
# Out:
#    emp_id        name  age    sal  appraisal  new_sal
# 0       1      Shashi   24  20000       1200    21200
# 1       2        Yash   23  25000       1200    26200
# 2       3       Veman   22   3000       1200     4200
# 3       4       Vansh   23  35000       1200    36200
# 4       5       Nikki   24  45000       1200    46200
# 5       6          Om   21  35678       1200    36878
# 6       7      Saiyam   25  34000       1200    35200
# 7       8  Vidyasagar   28  89000       1200    90200

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,5))
sns.histplot(emp["sal"], bins=5, kde=True)
plt.show()

# %%
#sorting employees by sal in descending order

sort_desc = emp.sort_values(by="new_sal" , ascending = False)
sort_desc
# Out:
#    emp_id        name  age    sal  appraisal  new_sal
# 7       8  Vidyasagar   28  89000       1200    90200
# 4       5       Nikki   24  45000       1200    46200
# 5       6          Om   21  35678       1200    36878
# 3       4       Vansh   23  35000       1200    36200
# 6       7      Saiyam   25  34000       1200    35200
# 1       2        Yash   23  25000       1200    26200
# 0       1      Shashi   24  20000       1200    21200
# 2       3       Veman   22   3000       1200     4200

# %%
#sort by age

sort_age = emp.sort_values(by="age", ascending=False)
sort_age
# Out:
#    emp_id        name  age    sal  appraisal  new_sal
# 7       8  Vidyasagar   28  89000       1200    90200
# 6       7      Saiyam   25  34000       1200    35200
# 0       1      Shashi   24  20000       1200    21200
# 4       5       Nikki   24  45000       1200    46200
# 1       2        Yash   23  25000       1200    26200
# 3       4       Vansh   23  35000       1200    36200
# 2       3       Veman   22   3000       1200     4200
# 5       6          Om   21  35678       1200    36878

# %%
#finding employees whose sal is greater than 45000

sal_emp = emp[emp["new_sal"] >= 45000]
sal_emp
# Out:
#    emp_id        name  age    sal  appraisal  new_sal
# 4       5       Nikki   24  45000       1200    46200
# 7       8  Vidyasagar   28  89000       1200    90200

# %%
#finding employees with sal > 30000 and age < 25

emp_sal_age = emp[(emp["new_sal"] > 30000) & (emp["age"] < 25)]
emp_sal_age
# Out:
#    emp_id   name  age    sal  appraisal  new_sal
# 3       4  Vansh   23  35000       1200    36200
# 4       5  Nikki   24  45000       1200    46200
# 5       6     Om   21  35678       1200    36878

# %%
#employees with sal >=20000 and age = 28

sal_emp_age = emp[(emp["sal"]>=20000) & (emp["age"] == 28)]
sal_emp_age
# Out:
#    emp_id        name  age    sal  appraisal  new_sal
# 7       8  Vidyasagar   28  89000       1200    90200

# %%
emp_name = emp[emp["name"] == "Shashi"]
emp_name
# Out:
#    emp_id    name  age    sal  appraisal  new_sal
# 0       1  Shashi   24  20000       1200    21200

# %%
dept = pd.DataFrame({
    "emp_id": [1,2,3,4,5,6,7,8],
    "dept_name": ["Consultant","IT","CS","DS","Consultant","IT","CS","Bcom"]
})

dept
# Out:
#    emp_id   dept_name
# 0       1  Consultant
# 1       2          IT
# 2       3          CS
# 3       4          DS
# 4       5  Consultant
# 5       6          IT
# 6       7          CS
# 7       8        Bcom

# %%
merge = pd.merge(emp,dept, on="emp_id")
merge
# Out:
#    emp_id        name  age    sal  appraisal  new_sal   dept_name
# 0       1      Shashi   24  20000       1200    21200  Consultant
# 1       2        Yash   23  25000       1200    26200          IT
# 2       3       Veman   22   3000       1200     4200          CS
# 3       4       Vansh   23  35000       1200    36200          DS
# 4       5       Nikki   24  45000       1200    46200  Consultant
# 5       6          Om   21  35678       1200    36878          IT
# 6       7      Saiyam   25  34000       1200    35200          CS
# 7       8  Vidyasagar   28  89000       1200    90200        Bcom

# %%
emp.drop("age", axis=1)

emp
# Out:
#    emp_id        name  age    sal  appraisal  new_sal
# 0       1      Shashi   24  20000       1200    21200
# 1       2        Yash   23  25000       1200    26200
# 2       3       Veman   22   3000       1200     4200
# 3       4       Vansh   23  35000       1200    36200
# 4       5       Nikki   24  45000       1200    46200
# 5       6          Om   21  35678       1200    36878
# 6       7      Saiyam   25  34000       1200    35200
# 7       8  Vidyasagar   28  89000       1200    90200

# %%
stud1 = pd.DataFrame({
    "stud_id": [1,2,3,4,5,6,7,8],
    "name": ["Shashi","Yash","Veman","Vansh","Nikki","Om","Saiyam","Vidyasagar"],
    "age": [24,23,22,23,24,21,25,28],
})

stud1
# Out:
#    stud_id        name  age
# 0        1      Shashi   24
# 1        2        Yash   23
# 2        3       Veman   22
# 3        4       Vansh   23
# 4        5       Nikki   24
# 5        6          Om   21
# 6        7      Saiyam   25
# 7        8  Vidyasagar   28

# %%
stud1.drop("age", axis=1)
# Out:
#    stud_id        name
# 0        1      Shashi
# 1        2        Yash
# 2        3       Veman
# 3        4       Vansh
# 4        5       Nikki
# 5        6          Om
# 6        7      Saiyam
# 7        8  Vidyasagar
